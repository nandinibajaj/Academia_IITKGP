# %% [markdown]
# **Nandini Bajaj 18CY20020**
#
# Lab Assignment 7

# %%
import pandas as pd
import numpy as np
import math
import random
import matplotlib.pyplot as plt

# %%
def cubic(l, n):
  count=0
  for i in range(7):
    for j in range(7):
      for k in range(7):
        config.append([l*k, l*j, l*i])
        count+=1
        if count == n:
          break

# %%
def fcc(l, n):
  count=0
  for i in range(16):
    for j in range(4):
      for k in range(4):
        if i%2 == 0:
          if j%2==0:
            config_fcc.append([k*l, j*l, (i%4)*l])
          else:
            config_fcc.append([l/2+k*l, l/2+j*l, l/2+(i%4)*l])
        else:
          if j%2!=0:
            config_fcc.append([k*l, j*l, (i%4)*l])
          else:
            config_fcc.append([l/2+k*l, l/2+j*l, l/2+(i%4)*l])

# %%
config_fcc=[]
config=[]
n=256
cubic(3.1034, n)
print("Coordinates for cubic configuration:")
for i in range(n):
  print(str(config[i][0])+"   "+str(config[i][1])+"   "+str(config[i][2]))

fcc(4.9264, n)
print("Coordinates for FCC configuration:")
for i in range(n):
  print(str(config_fcc[i][0])+"   "+str(config_fcc[i][1])+"   "+str(config_fcc[i][2]))
# Out:
# Coordinates for cubic configuration:
# 0.0   0.0   0.0
# 3.1034   0.0   0.0
# 6.2068   0.0   0.0
# 9.3102   0.0   0.0
# 12.4136   0.0   0.0
# 15.517000000000001   0.0   0.0
# 18.6204   0.0   0.0
# 0.0   3.1034   0.0
# 3.1034   3.1034   0.0
# 6.2068   3.1034   0.0
# 9.3102   3.1034   0.0
# 12.4136   3.1034   0.0
# 15.517000000000001   3.1034   0.0
# 18.6204   3.1034   0.0
# 0.0   6.2068   0.0
# 3.1034   6.2068   0.0
# 6.2068   6.2068   0.0
# 9.3102   6.2068   0.0
# 12.4136   6.2068   0.0
# 15.517000000000001   6.2068   0.0
# 18.6204   6.2068   0.0
# 0.0   9.3102   0.0
# 3.1034   9.3102   0.0
# 6.2068   9.3102   0.0
# 9.3102   9.3102   0.0
# 12.4136   9.3102   0.0
# 15.517000000000001   9.3102   0.0
# 18.6204   9.3102   0.0
# 0.0   12.4136   0.0
# 3.1034   12.4136   0.0
# 6.2068   12.4136   0.0
# 9.3102   12.4136   0.0
# 12.4136   12.4136   0.0
# 15.517000000000001   12.4136   0.0
# 18.6204   12.4136   0.0
# 0.0   15.517000000000001   0.0
# 3.1034   15.517000000000001   0.0
# ...

# %%
config
# Out:
# [[0.0, 0.0, 0.0],
#  [3.1034, 0.0, 0.0],
#  [6.2068, 0.0, 0.0],
#  [9.3102, 0.0, 0.0],
#  [12.4136, 0.0, 0.0],
#  [15.517000000000001, 0.0, 0.0],
#  [18.6204, 0.0, 0.0],
#  [0.0, 3.1034, 0.0],
#  [3.1034, 3.1034, 0.0],
#  [6.2068, 3.1034, 0.0],
#  [9.3102, 3.1034, 0.0],
#  [12.4136, 3.1034, 0.0],
#  [15.517000000000001, 3.1034, 0.0],
#  [18.6204, 3.1034, 0.0],
#  [0.0, 6.2068, 0.0],
#  [3.1034, 6.2068, 0.0],
#  [6.2068, 6.2068, 0.0],
#  [9.3102, 6.2068, 0.0],
#  [12.4136, 6.2068, 0.0],
#  [15.517000000000001, 6.2068, 0.0],
#  [18.6204, 6.2068, 0.0],
#  [0.0, 9.3102, 0.0],
#  [3.1034, 9.3102, 0.0],
#  [6.2068, 9.3102, 0.0],
#  [9.3102, 9.3102, 0.0],
#  [12.4136, 9.3102, 0.0],
#  [15.517000000000001, 9.3102, 0.0],
#  [18.6204, 9.3102, 0.0],
#  [0.0, 12.4136, 0.0],
#  [3.1034, 12.4136, 0.0],
#  [6.2068, 12.4136, 0.0],
#  [9.3102, 12.4136, 0.0],
#  [12.4136, 12.4136, 0.0],
#  [15.517000000000001, 12.4136, 0.0],
#  [18.6204, 12.4136, 0.0],
#  [0.0, 15.517000000000001, 0.0],
# ...

# %%
config_fcc
# Out:
# [[0.0, 0.0, 0.0],
#  [4.9264, 0.0, 0.0],
#  [9.8528, 0.0, 0.0],
#  [14.7792, 0.0, 0.0],
#  [2.4632, 7.3896, 2.4632],
#  [7.3896, 7.3896, 2.4632],
#  [12.316, 7.3896, 2.4632],
#  [17.2424, 7.3896, 2.4632],
#  [0.0, 9.8528, 0.0],
#  [4.9264, 9.8528, 0.0],
#  [9.8528, 9.8528, 0.0],
#  [14.7792, 9.8528, 0.0],
#  [2.4632, 17.2424, 2.4632],
#  [7.3896, 17.2424, 2.4632],
#  [12.316, 17.2424, 2.4632],
#  [17.2424, 17.2424, 2.4632],
#  [2.4632, 2.4632, 7.3896],
#  [7.3896, 2.4632, 7.3896],
#  [12.316, 2.4632, 7.3896],
#  [17.2424, 2.4632, 7.3896],
#  [0.0, 4.9264, 4.9264],
#  [4.9264, 4.9264, 4.9264],
#  [9.8528, 4.9264, 4.9264],
#  [14.7792, 4.9264, 4.9264],
#  [2.4632, 12.316, 7.3896],
#  [7.3896, 12.316, 7.3896],
#  [12.316, 12.316, 7.3896],
#  [17.2424, 12.316, 7.3896],
#  [0.0, 14.7792, 4.9264],
#  [4.9264, 14.7792, 4.9264],
#  [9.8528, 14.7792, 4.9264],
#  [14.7792, 14.7792, 4.9264],
#  [0.0, 0.0, 9.8528],
#  [4.9264, 0.0, 9.8528],
#  [9.8528, 0.0, 9.8528],
#  [14.7792, 0.0, 9.8528],
# ...

# %%
import csv
with open("cubic_config.csv","w+") as my_csv:
    csvWriter = csv.writer(my_csv,delimiter=',')
    csvWriter.writerows(config)

# %%
import csv
with open("fcc_config.csv","w+") as my_csv:
    csvWriter = csv.writer(my_csv,delimiter=',')
    csvWriter.writerows(config_fcc)
